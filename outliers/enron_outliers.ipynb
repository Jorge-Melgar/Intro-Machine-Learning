# %%
# %load enron_outliers.py
#!/usr/bin/python

import pickle
import sys
import matplotlib.pyplot

sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit


### read in data dictionary, convert to numpy array
data_dict = pickle.load( open("../final_project/final_project_dataset.pkl", "r") )
print(len(data_dict))
data_dict.pop('TOTAL') 
print(len(data_dict))
features = ["salary", "bonus"]
data = featureFormat(data_dict, features)


### your code below

for point in data:
    salary = point[0]
    bonus = point[1]
    matplotlib.pyplot.scatter( salary, bonus )

matplotlib.pyplot.xlabel("salary")
matplotlib.pyplot.ylabel("bonus")
matplotlib.pyplot.show()
# Out:
# 146
# 145

# %%
# Code to find the outlier on the original list

lista = []

for i in data_dict:
    if not data_dict[i]["bonus"] == "NaN":
        lista.append([i,data_dict[i]["salary"],data_dict[i]["bonus"]])

lista.sort(key=lambda x: x[1],reverse=True)
    
print(lista)
# Out:
# [['SKILLING JEFFREY K', 1111258, 5600000], ['LAY KENNETH L', 1072321, 7000000], ['FREVERT MARK A', 1060932, 2000000], ['PICKERING MARK R', 655037, 300000], ['WHALLEY LAWRENCE G', 510364, 3000000], ['DERRICK JR. JAMES V', 492375, 800000], ['FASTOW ANDREW S', 440698, 1300000], ['SHERRIFF JOHN R', 428780, 1500000], ['RICE KENNETH D', 420636, 1750000], ['CAUSEY RICHARD A', 415189, 1000000], ['KEAN STEVEN J', 404338, 1000000], ['HAEDICKE MARK E', 374125, 1150000], ['MCMAHON JEFFREY', 370448, 2600000], ['METTS MARK', 365788, 600000], ['DELAINEY DAVID W', 365163, 3000000], ['MCCONNELL MICHAEL S', 365038, 1100000], ['WALLS JR ROBERT H', 357091, 850000], ['LAVORATO JOHN J', 339288, 8000000], ['BUY RICHARD B', 330546, 900000], ['OLSON CINDY K', 329078, 750000], ['WHITE JR THOMAS E', 317543, 450000], ['COX DAVID', 314288, 800000], ['KOENIG MARK E', 309946, 700000], ['FALLON JAMES B', 304588, 2500000], ['SHANKMAN JEFFREY A', 304110, 2000000], ['UMANOFF ADAM S', 288589, 788750], ['JACKSON CHARLENE R', 288558, 250000], ['COLWELL WESLEY', 288542, 1200000], ['BOWEN JR RAYMOND M', 278601, 1350000], ['DONAHUE JR JEFFREY M', 278601, 800000], ['KAMINSKI WINCENTY J', 275101, 400000], ['GLISAN JR BEN F', 274975, 600000], ['LEFF DANIEL P', 273746, 1000000], ['GOLD JOSEPH', 272880, 750000], ['KITCHEN LOUISE', 271442, 3100000], ['SHAPIRO RICHARD S', 269076, 650000], ['BAXTER JOHN C', 267102, 1200000], ['MORDAUNT KRISTINA M', 267093, 325000], ['TAYLOR MITCHELL S', 265214, 600000], ['MCCLELLAN GEORGE', 263413, 900000], ['DIMICHELE RICHARD G', 262788, 1000000], ['HERMANN ROBERT J', 262663, 700000], ['PAI LOU L', 261879, 1000000], ['CARTER REBECCA C', 261809, 300000], ['BUTTS ROBERT H', 261516, 750000], ['WASAFF GEORGE', 259996, 325000], ['SUNDE MARTIN', 257486, 700000], ['MULLER MARK S', 251654, 1100000], ['DIETRICH JANET R', 250100, 600000], ['RIEKER PAULA H', 249201, 700000], ['BLACHMAN JEREMY M', 248546, 850000], ['SHARP VICTORIA T', 248146, 600000], ['BUCHANAN HAROLD G', 248017, 500000], ['TILNEY ELIZABETH A', 247338, 300000], ['HANNON KEVIN P', 243293, 1500000], ['CALGER CHRISTOPHER F', 240189, 1250000], ['BAY FRANKLIN R', 239671, 400000], ['STABLER FRANK', 239502, 500000], ['LINDHOLM TOD A', 236457, 200000], ['GARLAND C KEVIN', 231946, 850000], ['BECK SALLY W', 231330, 700000], ['MURRAY JULIA H', 229284, 400000], ['KOPPER MICHAEL J', 224305, 800000], ['DODSON KEITH', 221003, 70000], ['BELDEN TIMOTHY N', 213999, 5249999], ['BIBI PHILIPPE A', 213625, 1000000], ['SHELBY REX', 211844, 200000], ['HICKERSON GARY J', 211788, 1700000], ['DURAN WILLIAM D', 210692, 750000], ['DETMERING TIMOTHY J', 210500, 425000], ['DEFFNER JOSEPH M', 206121, 600000], ['ALLEN PHILLIP K', 201955, 4175000], ['FITZGERALD JAY L', 199157, 350000], ['PIPER GREGORY F', 197091, 400000], ['GAHN ROBERT S', 192008, 509870], ['BERGSIEKER RICHARD P', 187922, 250000], ['CUMBERLAND MICHAEL S', 184899, 325000], ['ECHOLS JOHN B', 182245, 200000], ['ELLIOTT STEVEN', 170941, 350000], ['SULLIVAN-SHAKLOVITZ COLLEEN', 162779, 100000], ['REYNOLDS LAWRENCE', 76399, 100000]]
